# %%
import pandas as pd

# %%
pd_merged = pd.read_csv('merged_data.csv')
display(pd_merged)
# Out:
#             Country  Year      Status  Population  Hepatitis B  Measles  \
# 0       Afghanistan  2015  Developing  33736494.0         65.0     1154
# 1       Afghanistan  2015  Developing  33736494.0         65.0     1154
# 2       Afghanistan  2015  Developing  33736494.0         65.0     1154
# 3       Afghanistan  2015  Developing  33736494.0         65.0     1154
# 4       Afghanistan  2015  Developing  33736494.0         65.0     1154
# ...             ...   ...         ...         ...          ...      ...
# 459195     Zimbabwe  2000  Developing  12222251.0         79.0     1483
# 459196     Zimbabwe  2000  Developing  12222251.0         79.0     1483
# 459197     Zimbabwe  2000  Developing  12222251.0         79.0     1483
# 459198     Zimbabwe  2000  Developing  12222251.0         79.0     1483
# 459199     Zimbabwe  2000  Developing  12222251.0         79.0     1483
#
#         Polio  Diphtheria  HIV/AIDS  infant deaths  ...  thinness  1-19 years  \
# ...
